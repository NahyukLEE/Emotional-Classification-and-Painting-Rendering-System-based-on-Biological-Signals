# %% [markdown]
# ## 1. Fast Fourier Transfrom(FFT)

# %%
import pandas as pd
import math
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
# fft 함수 'get_data' 정의
def get_data(data):
    # eegRawValueVolts column 이용
    data = data['eegRawValueVolts']
    # 1초에서 25초까지의 데이터만 추출
    data = data.iloc[range(100,2500,1)]
    length = len(data)
    # Fast Fourier Transform (numpy 이용)
    fft = np.fft.fft(data)
    fft_magnitude = np.abs(fft)
    fft_spectrum = np.square(fft_magnitude)
    ifft = np.fft.ifft(fft_magnitude)
    
    # 1200을 기준으로 대칭. 우측 데이터만 이용
    fft_spec = fft_spectrum[1200:2400]
    return fft_spec

# %%
# fft 확인
num = 1

for n in range(num):
    name = 'data/sad_' + str(n) +'.csv'
    data = pd.read_csv(name, error_bad_lines=False)
    fft_spec = get_data(data)

# %%
len(fft_spec)
# Out:
# 1200

# %% [markdown]
# ## 뇌파 종류와 주파수 범위[Hz] 정의 및 뇌파 별 분류
# * Delta frequency : 0.1 - 4
# * Theta frequency : 4 - 8
# * AlphaLow frequency : 8 - 10
# * AlphaHigh frequency : 10 - 13
# * BetaLow frequency : 13 - 18
# * BetaHigh frequency : 18 - 30
# * GammaLow frequency : 30 - 40
# * GammaMid frequency : 40 - 50

# %%
# 각 뇌파 사이 criteria 정의
start_cri = int(1200 / 50 * 0.1)
DT_cri = int(1200 / 50 * 4)
TAl_cri = int(1200 / 50 * 8)
AlAh_cri = int(1200 / 50 * 10)
AhBl_cri = int(1200 / 50 * 13)
BlBh_cri = int(1200 / 50 * 18)
BhGl_cri = int(1200 / 50 * 30)
GlGm_cri = int(1200 / 50 * 40)

# %%
# 뇌파 별 분류
Delta = fft_spec[start_cri:DT_cri]
Theta = fft_spec[DT_cri:TAl_cri]
AlphaLow = fft_spec[TAl_cri:AlAh_cri]
AlphaHigh = fft_spec[AlAh_cri:AhBl_cri]
BetaLow = fft_spec[AhBl_cri:BlBh_cri]
BetaHigh = fft_spec[BlBh_cri:BhGl_cri]
GammaLow = fft_spec[BhGl_cri:GlGm_cri]
GammaMid = fft_spec[GlGm_cri:]

# %% [markdown]
# ## 2. DataFrame 생성

# %% [markdown]
# * Happy DataFrame (target = 0)

# %%
# DataFrame 생성 함수 정의
def get_result_df(emotion, num_data, target):
    temp_df = pd.DataFrame()
    brain_wave = ['Delta', 'Theta', 'AlphaLow', 'AlphaHigh', 'BetaLow', 'BetaHigh',
              'GammaLow', 'GammaMid']

    for n in range(num_data+1):
        name = 'data/'+ emotion + '_' + str(n) +'.csv'
        data = pd.read_csv(name, error_bad_lines=False)
        fft_spec = get_data(data)
        # 뇌파 분류 및 비율 계산
        Delta = fft_spec[start_cri:DT_cri].sum() / len(fft_spec[start_cri:DT_cri]) 
        Theta = fft_spec[DT_cri:TAl_cri].sum() / len(fft_spec[DT_cri:TAl_cri])
        AlphaLow = fft_spec[TAl_cri:AlAh_cri].sum() / len(fft_spec[TAl_cri:AlAh_cri])
        AlphaHigh = fft_spec[AlAh_cri:AhBl_cri].sum() / len(fft_spec[AlAh_cri:AhBl_cri])
        BetaLow = fft_spec[AhBl_cri:BlBh_cri].sum() / len(fft_spec[AhBl_cri:BlBh_cri])
        BetaHigh = fft_spec[BlBh_cri:BhGl_cri].sum() / len(fft_spec[BlBh_cri:BhGl_cri])
        GammaLow = fft_spec[BhGl_cri:GlGm_cri].sum() / len(fft_spec[BhGl_cri:GlGm_cri])
        GammaMid = fft_spec[GlGm_cri:].sum() / len(fft_spec[GlGm_cri:])
        # DataFrame record 생성
        new_row = {'Delta':Delta, 'Theta':Theta, 'AlphaLow':AlphaLow, 
           'AlphaHigh':AlphaHigh, 'BetaLow':BetaLow, 'BetaHigh':BetaHigh, 
           'GammaLow':GammaLow, 'GammaMid':GammaMid}
        temp_df = temp_df.append(pd.Series(new_row), ignore_index=True)

    temp_df = temp_df[brain_wave]
    # Record별 brain wave 비율 계산
    temp_df['sum'] = temp_df.sum(axis=1)
    for wave in brain_wave:
        temp_df[wave] = temp_df[wave] / temp_df['sum']
    temp_df.drop('sum', axis=1, inplace=True)
    temp_df['target'] = target

    return temp_df

# %%
# happy_df target = 0
# happy data: 45개
happy_df = get_result_df('happy', num_data = 45, target = 0)
happy_df
# Out:
#        Delta     Theta  AlphaLow  AlphaHigh   BetaLow  BetaHigh  GammaLow  \
# 0   0.096494  0.106731  0.089205   0.129719  0.165946  0.198439  0.107642
# 1   0.022036  0.024554  0.025769   0.025837  0.026813  0.038597  0.153249
# 2   0.172285  0.167949  0.166167   0.118133  0.104320  0.099117  0.067440
# 3   0.163685  0.141831  0.159324   0.159762  0.122647  0.090905  0.065070
# 4   0.159220  0.138152  0.133228   0.162818  0.100186  0.078691  0.079785
# 5   0.113149  0.140680  0.127053   0.123583  0.134637  0.091740  0.078748
# 6   0.112069  0.119619  0.088493   0.100698  0.088123  0.083534  0.124615
# 7   0.036965  0.052199  0.055203   0.046723  0.058893  0.056045  0.121493
# 8   0.028361  0.025969  0.020604   0.020564  0.030564  0.050358  0.140159
# 9   0.085977  0.104100  0.084520   0.123948  0.180413  0.163605  0.121590
# 10  0.114804  0.075066  0.070262   0.089976  0.099025  0.084266  0.161153
# 11  0.092744  0.082229  0.086221   0.108802  0.134967  0.164811  0.110780
# 12  0.058400  0.072453  0.066846   0.060899  0.076832  0.119684  0.200035
# 13  0.053073  0.055123  0.046953   0.069018  0.071154  0.105471  0.169943
# 14  0.028988  0.032902  0.043129   0.041126  0.041465  0.062582  0.176221
# 15  0.048270  0.056244  0.060108   0.048169  0.061807  0.086208  0.209400
# 16  0.073285  0.081382  0.064593   0.072690  0.084416  0.103435  0.180506
# 17  0.041824  0.044024  0.038028   0.049023  0.053009  0.057576  0.154884
# 18  0.067072  0.065947  0.069842   0.062637  0.067034  0.093943  0.151428
# 19  0.073097  0.067115  0.048852   0.082737  0.083524  0.095364  0.212893
# 20  0.066365  0.068233  0.046605   0.065819  0.061092  0.090604  0.197836
# 21  0.022982  0.039469  0.036258   0.031575  0.051853  0.054270  0.189689
# 22  0.058244  0.086069  0.061332   0.091969  0.075509  0.094664  0.174523
# 23  0.047846  0.055632  0.046169   0.058568  0.054218  0.074858  0.176177
# 24  0.034938  0.043052  0.058355   0.041331  0.043439  0.064124  0.213800
# 25  0.033114  0.030691  0.023333   0.043362  0.044372  0.093520  0.198753
# 26  0.047384  0.032793  0.026986   0.035638  0.050607  0.052356  0.198567
# 27  0.041864  0.052574  0.063733   0.040696  0.073423  0.092863  0.193681
# 28  0.024074  0.045439  0.030464   0.038555  0.040602  0.062197  0.220953
# 29  0.040880  0.037929  0.043684   0.038704  0.039862  0.055433  0.099446
# 30  0.087091  0.060843  0.055157   0.030135  0.035035  0.082522  0.178623
# 31  0.088208  0.087513  0.085475   0.058275  0.057688  0.101366  0.137934
# 32  0.031194  0.041509  0.035449   0.054761  0.047740  0.058142  0.124660
# 33  0.104929  0.055331  0.058792   0.059024  0.098844  0.091637  0.175279
# 34  0.062739  0.062051  0.055987   0.043982  0.039456  0.109768  0.131815
# 35  0.042613  0.035676  0.058744   0.033343  0.047933  0.061866  0.181632
# 36  0.025146  0.035384  0.031835   0.039733  0.030006  0.054988  0.158618
# 37  0.023858  0.019699  0.030536   0.022481  0.037161  0.043793  0.118753
# 38  0.022560  0.020618  0.026644   0.029892  0.030293  0.055516  0.137800
# 39  0.026920  0.022353  0.028100   0.034541  0.029692  0.041142  0.113998
# 40  0.073464  0.073914  0.071132   0.112824  0.085370  0.107693  0.157492
# 41  0.036937  0.032919  0.030926   0.030943  0.030951  0.038663  0.124565
# 42  0.031608  0.033781  0.032281   0.042802  0.036841  0.040959  0.118637
# 43  0.028729  0.023937  0.033671   0.035724  0.035897  0.041888  0.128800
# 44  0.031299  0.032580  0.023146   0.073472  0.042104  0.043083  0.136989
# 45  0.075375  0.057571  0.039028   0.060323  0.078684  0.077326  0.277410
#
#     GammaMid  target
# 0   0.105825       0
# 1   0.683145       0
# 2   0.104588       0
# 3   0.096776       0
# 4   0.147920       0
# 5   0.190410       0
# 6   0.282849       0
# 7   0.572480       0
# 8   0.683420       0
# 9   0.135846       0
# 10  0.305447       0
# 11  0.219446       0
# 12  0.344850       0
# 13  0.429265       0
# 14  0.573587       0
# 15  0.429793       0
# 16  0.339695       0
# 17  0.561631       0
# 18  0.422097       0
# 19  0.336418       0
# 20  0.403445       0
# 21  0.573904       0
# 22  0.357690       0
# 23  0.486533       0
# 24  0.500961       0
# 25  0.532855       0
# 26  0.555668       0
# 27  0.441166       0
# 28  0.537717       0
# 29  0.644061       0
# 30  0.470593       0
# 31  0.383541       0
# 32  0.606546       0
# 33  0.356164       0
# 34  0.494201       0
# 35  0.538193       0
# 36  0.624290       0
# 37  0.703720       0
# 38  0.676676       0
# 39  0.703254       0
# 40  0.318112       0
# 41  0.674096       0
# 42  0.663092       0
# 43  0.671355       0
# 44  0.617327       0
# 45  0.334282       0

# %% [markdown]
# * Sad DataFrame (target = 1)

# %%
# sad_df target = 1
# sad data: 66개
sad_df = get_result_df('sad', num_data = 66, target = 1)
sad_df
# Out:
#        Delta     Theta  AlphaLow  AlphaHigh   BetaLow  BetaHigh  GammaLow  \
# 0   0.104271  0.105994  0.122069   0.124697  0.163349  0.190169  0.086072
# 1   0.035179  0.035861  0.036640   0.034406  0.041011  0.066837  0.413901
# 2   0.108910  0.117642  0.119850   0.121690  0.133633  0.181790  0.097334
# 3   0.108341  0.119117  0.130316   0.135112  0.164113  0.144437  0.079628
# 4   0.117082  0.150969  0.120062   0.114594  0.149157  0.140734  0.088972
# ..       ...       ...       ...        ...       ...       ...       ...
# 62  0.094571  0.115546  0.098483   0.117998  0.125311  0.195814  0.134940
# 63  0.088631  0.122254  0.077383   0.089573  0.136349  0.204753  0.142113
# 64  0.040880  0.037929  0.043684   0.038704  0.039862  0.055433  0.099446
# 65  0.107063  0.117493  0.105248   0.101619  0.126445  0.195476  0.127561
# 66  0.078111  0.094510  0.129585   0.107337  0.151042  0.201190  0.115598
#
#     GammaMid  target
# 0   0.103379       1
# 1   0.336165       1
# 2   0.119151       1
# 3   0.118935       1
# 4   0.118430       1
# ..       ...     ...
# 62  0.117338       1
# 63  0.138945       1
# 64  0.644061       1
# 65  0.119096       1
# 66  0.122627       1
#
# [67 rows x 9 columns]

# %%
# result datafrmae 생성 (happy, sad dataframe)
result_df = happy_df.append(sad_df, ignore_index=True)

result_df.to_csv('data/result_df.csv', index=False)

# %%
print(result_df.shape)
result_df.head()
# Out:
# (113, 9)
#       Delta     Theta  AlphaLow  AlphaHigh   BetaLow  BetaHigh  GammaLow  \
# 0  0.096494  0.106731  0.089205   0.129719  0.165946  0.198439  0.107642
# 1  0.022036  0.024554  0.025769   0.025837  0.026813  0.038597  0.153249
# 2  0.172285  0.167949  0.166167   0.118133  0.104320  0.099117  0.067440
# 3  0.163685  0.141831  0.159324   0.159762  0.122647  0.090905  0.065070
# 4  0.159220  0.138152  0.133228   0.162818  0.100186  0.078691  0.079785
#
#    GammaMid  target
# 0  0.105825       0
# 1  0.683145       0
# 2  0.104588       0
# 3  0.096776       0
# 4  0.147920       0

# %% [markdown]
# ## 3. Data preprocessing

# %% [markdown]
# ### * happy, sad 파장 별 correlation 확인

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import StratifiedShuffleSplit

# %%
sns.pairplot(result_df, 
             diag_kind='kde',
             hue="target", 
             palette='bright')
plt.show()

# %% [markdown]
# ### * Boxplot - outlier 확인

# %%
brain_waves = list(result_df.columns[:8])

fig, axes = plt.subplots(4, 2, figsize=(10, 15))
for i, wave in enumerate(brain_waves):
        box = axes[i//2, i%2].boxplot([result_df[result_df['target'] == 0][wave], 
                                       result_df[result_df['target'] == 1][wave]], patch_artist=True)
        axes[i//2, i%2].set_title(wave, fontsize=14)
        axes[i//2, i%2].set_xticklabels(['happy', 'sad'], fontsize=12)
        colors = ['lightblue', 'pink']
        for patch, color in zip(box['boxes'], colors):
            patch.set_facecolor(color)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### * outlier 제거

# %%
# train, test 데이터 분리 (stratified split)
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
for train_idx, test_idx in split.split(result_df, result_df["target"]):
    df_train = result_df.loc[train_idx]
    df_test = result_df.loc[test_idx]

data_copy = result_df.copy()
data_copy_train = df_train.copy()

# 50개의 노드 수, 최대 50개의 샘플
# 0.04%의 outlier 색출.
clf=IsolationForest(n_estimators=50, max_samples=50, contamination=float(0.2), 
                        max_features=1.0, bootstrap=False, n_jobs=-1, random_state=None, verbose=0,behaviour="new")
# 전체 data set의 oulier
clf.fit(data_copy)
pred = clf.predict(data_copy)
data_copy['anomaly']=pred
outliers_1=data_copy.loc[data_copy['anomaly']==-1]
outlier_index_1=list(outliers_1.index)

# train data의 oulier
clf.fit(data_copy_train)
pred = clf.predict(data_copy_train)
data_copy_train['anomaly']=pred
outliers_2=data_copy_train.loc[data_copy_train['anomaly']==-1]
outlier_index_2=list(outliers_2.index)

print('train_data')
print(data_copy_train['anomaly'].value_counts())
# Out:
# train_data
#  1    72
# -1    18
# Name: anomaly, dtype: int64

# %%
# 전체 dataset와 train data outlier 3D
pca = PCA(n_components=3) 
scaler = StandardScaler()
#normalize the metrics
X = scaler.fit_transform(data_copy)
X_reduce = pca.fit_transform(X)
X_oe = scaler.fit_transform(data_copy_train)
X_oe_reduce = pca.fit_transform(X_oe)

fig = plt.figure(figsize=(10, 5))
axes[0] = fig.add_subplot(121, projection='3d')
axes[1] = fig.add_subplot(122, projection='3d')
# 전체 dataset와 train data의 inliers plot - green
axes[0].scatter(X_reduce[:, 0], X_reduce[:, 1], zs=X_reduce[:, 2], s=4, lw=1,c="green")
axes[1].scatter(X_oe_reduce[:, 0], X_oe_reduce[:, 1], zs=X_oe_reduce[:, 2], s=4, lw=1, label="inliers",c="green")
# 전체 dataset와 train data의 outliers plot - red
axes[0].scatter(X_reduce[outlier_index_1,0],X_reduce[outlier_index_1,1], X_reduce[outlier_index_1,2],
           lw=2, s=60, marker="x", c="red")
axes[1].scatter(X_oe_reduce[outlier_index_2,0],X_oe_reduce[outlier_index_2,1], X_oe_reduce[outlier_index_2,2],
           lw=2, s=60, marker="x", c="red", label="outliers")
axes[0].set_title('all of dataset')
axes[1].set_title('train set')
fig.legend()
plt.show()

# %%
# 전체 dataset와 train data outlier 2D
pca_1 = PCA(2)
pca_1.fit(data_copy)
pca_2 = PCA(2)
pca_2.fit(data_copy_train)
res_1=pd.DataFrame(pca_1.transform(data_copy))
res_2=pd.DataFrame(pca_2.transform(data_copy_train))

fig, axes = plt.subplots(1, 2, figsize=(9, 4))
fig.suptitle("IsolationForest", fontsize=14)
# 전체 dataset와 train data의 inliers plot - green
axes[0].scatter(res_1[0], res_1[1], c='green',s=20,label="normal points")
axes[1].scatter(res_2[0], res_2[1], c='green',s=20)
# 전체 dataset와 train data의 outliers plot - red
axes[0].scatter(res_1.iloc[outlier_index_1,0],res_1.iloc[outlier_index_1,1], c='red',s=20, label="predicted outliers")
axes[1].scatter(res_2.iloc[outlier_index_2,0],res_2.iloc[outlier_index_2,1], c='red',s=20)
axes[0].set_title('all of dataset')
axes[1].set_title('train set')
fig.legend(loc="right",  bbox_to_anchor=(1.24, 0.75))
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
data_copy_train = data_copy_train[data_copy_train['anomaly']==1]
data_copy_train.drop('anomaly', axis=1, inplace=True)

# %%
# outlier 제거 확인
fig, axes = plt.subplots(4, 2, figsize=(10, 15))
for i, wave in enumerate(brain_waves):
        box = axes[i//2, i%2].boxplot([data_copy_train[data_copy_train['target'] == 0][wave],
                                       data_copy_train[data_copy_train['target'] == 1][wave]], patch_artist=True)
        axes[i//2, i%2].set_title(wave, fontsize=14)
        axes[i//2, i%2].set_xticklabels(['happy', 'sad'], fontsize=12)
        colors = ['lightblue', 'pink']
        for patch, color in zip(box['boxes'], colors):
            patch.set_facecolor(color)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Modeling - Lightgbm

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
X_train = df_train.drop(['target'], axis=1)
y_train = df_train['target']
X_test = df_test.drop(['target'], axis=1)
y_test = df_test['target']

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (90, 8) (23, 8)
# (90,) (23,)

# %% [markdown]
# ### * outlier 제거되지 않은 데이터로 학습 및 평가

# %%
lgbm_wrapper = LGBMClassifier(n_estimators=400, objective='binary')

evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=10, eval_metric="logloss", 
                 eval_set=evals, verbose=True)
# Out:
# [1]	valid_0's binary_logloss: 0.621625
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.579164
# [3]	valid_0's binary_logloss: 0.544321
# [4]	valid_0's binary_logloss: 0.513025
# [5]	valid_0's binary_logloss: 0.487335
# [6]	valid_0's binary_logloss: 0.465355
# [7]	valid_0's binary_logloss: 0.441206
# [8]	valid_0's binary_logloss: 0.429251
# [9]	valid_0's binary_logloss: 0.413226
# [10]	valid_0's binary_logloss: 0.404144
# [11]	valid_0's binary_logloss: 0.394028
# [12]	valid_0's binary_logloss: 0.376768
# [13]	valid_0's binary_logloss: 0.375907
# [14]	valid_0's binary_logloss: 0.362809
# [15]	valid_0's binary_logloss: 0.350503
# [16]	valid_0's binary_logloss: 0.340341
# [17]	valid_0's binary_logloss: 0.335957
# [18]	valid_0's binary_logloss: 0.324348
# [19]	valid_0's binary_logloss: 0.317528
# [20]	valid_0's binary_logloss: 0.299886
# [21]	valid_0's binary_logloss: 0.284563
# [22]	valid_0's binary_logloss: 0.271245
# [23]	valid_0's binary_logloss: 0.261729
# [24]	valid_0's binary_logloss: 0.258339
# [25]	valid_0's binary_logloss: 0.256967
# [26]	valid_0's binary_logloss: 0.240032
# [27]	valid_0's binary_logloss: 0.238736
# [28]	valid_0's binary_logloss: 0.224472
# [29]	valid_0's binary_logloss: 0.214753
# [30]	valid_0's binary_logloss: 0.213136
# [31]	valid_0's binary_logloss: 0.203692
# [32]	valid_0's binary_logloss: 0.192397
# [33]	valid_0's binary_logloss: 0.181694
# [34]	valid_0's binary_logloss: 0.181551
# [35]	valid_0's binary_logloss: 0.177633
# [36]	valid_0's binary_logloss: 0.177658
# [37]	valid_0's binary_logloss: 0.178405
# [38]	valid_0's binary_logloss: 0.169232
# [39]	valid_0's binary_logloss: 0.169959
# [40]	valid_0's binary_logloss: 0.16883
# [41]	valid_0's binary_logloss: 0.166196
# [42]	valid_0's binary_logloss: 0.166808
# [43]	valid_0's binary_logloss: 0.16408
# [44]	valid_0's binary_logloss: 0.164647
# [45]	valid_0's binary_logloss: 0.160944
# [46]	valid_0's binary_logloss: 0.159877
# [47]	valid_0's binary_logloss: 0.154244
# [48]	valid_0's binary_logloss: 0.154942
# [49]	valid_0's binary_logloss: 0.152418
# [50]	valid_0's binary_logloss: 0.153097
# [51]	valid_0's binary_logloss: 0.150708
# [52]	valid_0's binary_logloss: 0.148358
# [53]	valid_0's binary_logloss: 0.145245
# [54]	valid_0's binary_logloss: 0.144043
# [55]	valid_0's binary_logloss: 0.139438
# [56]	valid_0's binary_logloss: 0.137734
# [57]	valid_0's binary_logloss: 0.138381
# [58]	valid_0's binary_logloss: 0.134805
# [59]	valid_0's binary_logloss: 0.135343
# [60]	valid_0's binary_logloss: 0.133732
# [61]	valid_0's binary_logloss: 0.130716
# [62]	valid_0's binary_logloss: 0.124117
# [63]	valid_0's binary_logloss: 0.124521
# [64]	valid_0's binary_logloss: 0.124858
# [65]	valid_0's binary_logloss: 0.120616
# [66]	valid_0's binary_logloss: 0.120961
# [67]	valid_0's binary_logloss: 0.118837
# [68]	valid_0's binary_logloss: 0.113337
# [69]	valid_0's binary_logloss: 0.113683
# [70]	valid_0's binary_logloss: 0.11356
# [71]	valid_0's binary_logloss: 0.111664
# [72]	valid_0's binary_logloss: 0.106544
# [73]	valid_0's binary_logloss: 0.103591
# [74]	valid_0's binary_logloss: 0.103347
# [75]	valid_0's binary_logloss: 0.103187
# [76]	valid_0's binary_logloss: 0.103548
# [77]	valid_0's binary_logloss: 0.102003
# [78]	valid_0's binary_logloss: 0.099168
# [79]	valid_0's binary_logloss: 0.0994411
# [80]	valid_0's binary_logloss: 0.0994089
# [81]	valid_0's binary_logloss: 0.0979548
# [82]	valid_0's binary_logloss: 0.0956475
# [83]	valid_0's binary_logloss: 0.0918241
# [84]	valid_0's binary_logloss: 0.0928013
# [85]	valid_0's binary_logloss: 0.0918209
# [86]	valid_0's binary_logloss: 0.0928312
# [87]	valid_0's binary_logloss: 0.0906929
# [88]	valid_0's binary_logloss: 0.0905734
# [89]	valid_0's binary_logloss: 0.0914708
# [90]	valid_0's binary_logloss: 0.0902869
# [91]	valid_0's binary_logloss: 0.0901204
# [92]	valid_0's binary_logloss: 0.0890331
# [93]	valid_0's binary_logloss: 0.0854213
# [94]	valid_0's binary_logloss: 0.0863223
# [95]	valid_0's binary_logloss: 0.0862097
# [96]	valid_0's binary_logloss: 0.0844556
# [97]	valid_0's binary_logloss: 0.0835693
# [98]	valid_0's binary_logloss: 0.0842543
# [99]	valid_0's binary_logloss: 0.0832524
# [100]	valid_0's binary_logloss: 0.0840476
# [101]	valid_0's binary_logloss: 0.0831308
# [102]	valid_0's binary_logloss: 0.0821674
# [103]	valid_0's binary_logloss: 0.0829201
# [104]	valid_0's binary_logloss: 0.0836424
# [105]	valid_0's binary_logloss: 0.0827081
# [106]	valid_0's binary_logloss: 0.0811812
# [107]	valid_0's binary_logloss: 0.0780907
# [108]	valid_0's binary_logloss: 0.0787679
# [109]	valid_0's binary_logloss: 0.0794191
# [110]	valid_0's binary_logloss: 0.0790667
# [111]	valid_0's binary_logloss: 0.0776423
# [112]	valid_0's binary_logloss: 0.0745578
# [113]	valid_0's binary_logloss: 0.0751836
# [114]	valid_0's binary_logloss: 0.0744017
# [115]	valid_0's binary_logloss: 0.0749602
# [116]	valid_0's binary_logloss: 0.0741487
# [117]	valid_0's binary_logloss: 0.0738368
# [118]	valid_0's binary_logloss: 0.0711566
# [119]	valid_0's binary_logloss: 0.070894
# [120]	valid_0's binary_logloss: 0.0682629
# [121]	valid_0's binary_logloss: 0.0688904
# [122]	valid_0's binary_logloss: 0.0686825
# [123]	valid_0's binary_logloss: 0.0663138
# [124]	valid_0's binary_logloss: 0.0668304
# [125]	valid_0's binary_logloss: 0.0662316
# [126]	valid_0's binary_logloss: 0.0659618
# [127]	valid_0's binary_logloss: 0.0665343
# [128]	valid_0's binary_logloss: 0.0659324
# [129]	valid_0's binary_logloss: 0.0656395
# [130]	valid_0's binary_logloss: 0.0661888
# [131]	valid_0's binary_logloss: 0.0659837
# [132]	valid_0's binary_logloss: 0.066551
# [133]	valid_0's binary_logloss: 0.0650933
# [134]	valid_0's binary_logloss: 0.064525
# [135]	valid_0's binary_logloss: 0.0637577
# [136]	valid_0's binary_logloss: 0.0616027
# [137]	valid_0's binary_logloss: 0.0610348
# [138]	valid_0's binary_logloss: 0.0589873
# [139]	valid_0's binary_logloss: 0.0595633
# [140]	valid_0's binary_logloss: 0.0596911
# [141]	valid_0's binary_logloss: 0.0602571
# [142]	valid_0's binary_logloss: 0.0593306
# [143]	valid_0's binary_logloss: 0.059037
# [144]	valid_0's binary_logloss: 0.0594685
# [145]	valid_0's binary_logloss: 0.058907
# [146]	valid_0's binary_logloss: 0.0585442
# [147]	valid_0's binary_logloss: 0.0578637
# [148]	valid_0's binary_logloss: 0.0582567
# [149]	valid_0's binary_logloss: 0.058006
# [150]	valid_0's binary_logloss: 0.0584474
# [151]	valid_0's binary_logloss: 0.0576456
# [152]	valid_0's binary_logloss: 0.058005
# [153]	valid_0's binary_logloss: 0.0580155
# [154]	valid_0's binary_logloss: 0.0563971
# [155]	valid_0's binary_logloss: 0.0567785
# [156]	valid_0's binary_logloss: 0.0563323
# [157]	valid_0's binary_logloss: 0.0559422
# [158]	valid_0's binary_logloss: 0.055583
# [159]	valid_0's binary_logloss: 0.0559227
# [160]	valid_0's binary_logloss: 0.0558712
# [161]	valid_0's binary_logloss: 0.0553965
# [162]	valid_0's binary_logloss: 0.0550852
# [163]	valid_0's binary_logloss: 0.0543425
# [164]	valid_0's binary_logloss: 0.0546807
# [165]	valid_0's binary_logloss: 0.0550164
# [166]	valid_0's binary_logloss: 0.0544105
# [167]	valid_0's binary_logloss: 0.054195
# [168]	valid_0's binary_logloss: 0.0544745
# [169]	valid_0's binary_logloss: 0.0537532
# [170]	valid_0's binary_logloss: 0.0532588
# [171]	valid_0's binary_logloss: 0.0526752
# [172]	valid_0's binary_logloss: 0.0516778
# [173]	valid_0's binary_logloss: 0.0519902
# [174]	valid_0's binary_logloss: 0.0514162
# [175]	valid_0's binary_logloss: 0.0516707
# [176]	valid_0's binary_logloss: 0.0510786
# [177]	valid_0's binary_logloss: 0.0513178
# [178]	valid_0's binary_logloss: 0.0508486
# [179]	valid_0's binary_logloss: 0.0503526
# [180]	valid_0's binary_logloss: 0.0490285
# [181]	valid_0's binary_logloss: 0.0493267
# [182]	valid_0's binary_logloss: 0.0487769
# [183]	valid_0's binary_logloss: 0.0490019
# [184]	valid_0's binary_logloss: 0.0485784
# [185]	valid_0's binary_logloss: 0.0480932
# [186]	valid_0's binary_logloss: 0.0470638
# [187]	valid_0's binary_logloss: 0.0465707
# [188]	valid_0's binary_logloss: 0.0465358
# [189]	valid_0's binary_logloss: 0.0461335
# [190]	valid_0's binary_logloss: 0.0464144
# [191]	valid_0's binary_logloss: 0.0459588
# [192]	valid_0's binary_logloss: 0.04507
# [193]	valid_0's binary_logloss: 0.0447564
# [194]	valid_0's binary_logloss: 0.0439523
# [195]	valid_0's binary_logloss: 0.0435118
# [196]	valid_0's binary_logloss: 0.0432288
# [197]	valid_0's binary_logloss: 0.0435194
# [198]	valid_0's binary_logloss: 0.0430215
# [199]	valid_0's binary_logloss: 0.0422901
# [200]	valid_0's binary_logloss: 0.0418225
# [201]	valid_0's binary_logloss: 0.0415946
# [202]	valid_0's binary_logloss: 0.0413582
# [203]	valid_0's binary_logloss: 0.0416537
# [204]	valid_0's binary_logloss: 0.0415688
# [205]	valid_0's binary_logloss: 0.0409195
# [206]	valid_0's binary_logloss: 0.0404706
# [207]	valid_0's binary_logloss: 0.0407528
# [208]	valid_0's binary_logloss: 0.0401317
# [209]	valid_0's binary_logloss: 0.0395514
# [210]	valid_0's binary_logloss: 0.0391197
# [211]	valid_0's binary_logloss: 0.0392107
# [212]	valid_0's binary_logloss: 0.0389817
# [213]	valid_0's binary_logloss: 0.0389387
# [214]	valid_0's binary_logloss: 0.0383854
# [215]	valid_0's binary_logloss: 0.0380278
# [216]	valid_0's binary_logloss: 0.0375449
# [217]	valid_0's binary_logloss: 0.0372309
# [218]	valid_0's binary_logloss: 0.0367319
# [219]	valid_0's binary_logloss: 0.0367136
# [220]	valid_0's binary_logloss: 0.0369802
# [221]	valid_0's binary_logloss: 0.0371947
# [222]	valid_0's binary_logloss: 0.0367149
# [223]	valid_0's binary_logloss: 0.0364702
# [224]	valid_0's binary_logloss: 0.0364434
# [225]	valid_0's binary_logloss: 0.0362391
# [226]	valid_0's binary_logloss: 0.0364977
# [227]	valid_0's binary_logloss: 0.036064
# [228]	valid_0's binary_logloss: 0.0362454
# [229]	valid_0's binary_logloss: 0.0358871
# [230]	valid_0's binary_logloss: 0.0359839
# [231]	valid_0's binary_logloss: 0.0355545
# [232]	valid_0's binary_logloss: 0.0355117
# [233]	valid_0's binary_logloss: 0.0350774
# [234]	valid_0's binary_logloss: 0.0346945
# [235]	valid_0's binary_logloss: 0.0343638
# [236]	valid_0's binary_logloss: 0.0339468
# [237]	valid_0's binary_logloss: 0.0339343
# [238]	valid_0's binary_logloss: 0.034166
# [239]	valid_0's binary_logloss: 0.0338767
# [240]	valid_0's binary_logloss: 0.0334927
# [241]	valid_0's binary_logloss: 0.0334848
# [242]	valid_0's binary_logloss: 0.0335302
# [243]	valid_0's binary_logloss: 0.033618
# [244]	valid_0's binary_logloss: 0.0336081
# [245]	valid_0's binary_logloss: 0.0333467
# [246]	valid_0's binary_logloss: 0.0334371
# [247]	valid_0's binary_logloss: 0.0334237
# [248]	valid_0's binary_logloss: 0.0331645
# [249]	valid_0's binary_logloss: 0.0327176
# [250]	valid_0's binary_logloss: 0.032372
# [251]	valid_0's binary_logloss: 0.0319737
# [252]	valid_0's binary_logloss: 0.0318831
# [253]	valid_0's binary_logloss: 0.0321347
# [254]	valid_0's binary_logloss: 0.031815
# [255]	valid_0's binary_logloss: 0.0318149
# [256]	valid_0's binary_logloss: 0.0319556
# [257]	valid_0's binary_logloss: 0.0316982
# [258]	valid_0's binary_logloss: 0.031406
# [259]	valid_0's binary_logloss: 0.0313202
# [260]	valid_0's binary_logloss: 0.0313132
# [261]	valid_0's binary_logloss: 0.0315503
# [262]	valid_0's binary_logloss: 0.031114
# [263]	valid_0's binary_logloss: 0.031351
# [264]	valid_0's binary_logloss: 0.0313489
# [265]	valid_0's binary_logloss: 0.0311839
# [266]	valid_0's binary_logloss: 0.0307811
# [267]	valid_0's binary_logloss: 0.0310111
# [268]	valid_0's binary_logloss: 0.0310976
# [269]	valid_0's binary_logloss: 0.0307944
# [270]	valid_0's binary_logloss: 0.0307853
# [271]	valid_0's binary_logloss: 0.0306406
# [272]	valid_0's binary_logloss: 0.0308675
# [273]	valid_0's binary_logloss: 0.0308753
# [274]	valid_0's binary_logloss: 0.0306853
# [275]	valid_0's binary_logloss: 0.0307703
# [276]	valid_0's binary_logloss: 0.030404
# [277]	valid_0's binary_logloss: 0.0306147
# [278]	valid_0's binary_logloss: 0.0304082
# [279]	valid_0's binary_logloss: 0.0302503
# [280]	valid_0's binary_logloss: 0.0303591
# [281]	valid_0's binary_logloss: 0.0305678
# [282]	valid_0's binary_logloss: 0.0303561
# [283]	valid_0's binary_logloss: 0.0301683
# [284]	valid_0's binary_logloss: 0.030167
# [285]	valid_0's binary_logloss: 0.0302525
# [286]	valid_0's binary_logloss: 0.0301163
# [287]	valid_0's binary_logloss: 0.0299241
# [288]	valid_0's binary_logloss: 0.030028
# [289]	valid_0's binary_logloss: 0.0297584
# [290]	valid_0's binary_logloss: 0.0295444
# [291]	valid_0's binary_logloss: 0.0293627
# [292]	valid_0's binary_logloss: 0.029565
# [293]	valid_0's binary_logloss: 0.029311
# [294]	valid_0's binary_logloss: 0.0289666
# [295]	valid_0's binary_logloss: 0.0290718
# [296]	valid_0's binary_logloss: 0.0286727
# [297]	valid_0's binary_logloss: 0.0288698
# [298]	valid_0's binary_logloss: 0.0286903
# [299]	valid_0's binary_logloss: 0.0287931
# [300]	valid_0's binary_logloss: 0.0284707
# [301]	valid_0's binary_logloss: 0.0286636
# [302]	valid_0's binary_logloss: 0.0284899
# [303]	valid_0's binary_logloss: 0.0285965
# [304]	valid_0's binary_logloss: 0.0287762
# [305]	valid_0's binary_logloss: 0.0285951
# [306]	valid_0's binary_logloss: 0.0282681
# [307]	valid_0's binary_logloss: 0.0283778
# [308]	valid_0's binary_logloss: 0.0281332
# [309]	valid_0's binary_logloss: 0.0282948
# [310]	valid_0's binary_logloss: 0.0281024
# [311]	valid_0's binary_logloss: 0.0281999
# [312]	valid_0's binary_logloss: 0.0280213
# [313]	valid_0's binary_logloss: 0.0277265
# [314]	valid_0's binary_logloss: 0.0275018
# [315]	valid_0's binary_logloss: 0.0276824
# [316]	valid_0's binary_logloss: 0.0275059
# [317]	valid_0's binary_logloss: 0.0271823
# [318]	valid_0's binary_logloss: 0.0272837
# [319]	valid_0's binary_logloss: 0.0274666
# [320]	valid_0's binary_logloss: 0.0272806
# [321]	valid_0's binary_logloss: 0.0273798
# [322]	valid_0's binary_logloss: 0.0275552
# [323]	valid_0's binary_logloss: 0.027326
# [324]	valid_0's binary_logloss: 0.027015
# [325]	valid_0's binary_logloss: 0.0265953
# [326]	valid_0's binary_logloss: 0.0264119
# [327]	valid_0's binary_logloss: 0.0264892
# [328]	valid_0's binary_logloss: 0.0263205
# [329]	valid_0's binary_logloss: 0.0263961
# [330]	valid_0's binary_logloss: 0.0258196
# [331]	valid_0's binary_logloss: 0.0256756
# [332]	valid_0's binary_logloss: 0.0257473
# [333]	valid_0's binary_logloss: 0.0254959
# [334]	valid_0's binary_logloss: 0.0249696
# [335]	valid_0's binary_logloss: 0.0251012
# [336]	valid_0's binary_logloss: 0.0251669
# [337]	valid_0's binary_logloss: 0.0252866
# [338]	valid_0's binary_logloss: 0.0247364
# [339]	valid_0's binary_logloss: 0.0247995
# [340]	valid_0's binary_logloss: 0.0249201
# [341]	valid_0's binary_logloss: 0.0244673
# [342]	valid_0's binary_logloss: 0.0245283
# [343]	valid_0's binary_logloss: 0.0246506
# [344]	valid_0's binary_logloss: 0.0245478
# [345]	valid_0's binary_logloss: 0.0240599
# [346]	valid_0's binary_logloss: 0.0241184
# [347]	valid_0's binary_logloss: 0.0238642
# [348]	valid_0's binary_logloss: 0.0239478
# [349]	valid_0's binary_logloss: 0.0237206
# [350]	valid_0's binary_logloss: 0.023801
# [351]	valid_0's binary_logloss: 0.0239344
# [352]	valid_0's binary_logloss: 0.0236822
# [353]	valid_0's binary_logloss: 0.0237618
# [354]	valid_0's binary_logloss: 0.023546
# [355]	valid_0's binary_logloss: 0.0233924
# [356]	valid_0's binary_logloss: 0.0231676
# [357]	valid_0's binary_logloss: 0.0232468
# [358]	valid_0's binary_logloss: 0.0231341
# [359]	valid_0's binary_logloss: 0.0229805
# [360]	valid_0's binary_logloss: 0.0230316
# [361]	valid_0's binary_logloss: 0.0228359
# [362]	valid_0's binary_logloss: 0.0226674
# [363]	valid_0's binary_logloss: 0.0226633
# [364]	valid_0's binary_logloss: 0.0225687
# [365]	valid_0's binary_logloss: 0.0224057
# [366]	valid_0's binary_logloss: 0.0224519
# [367]	valid_0's binary_logloss: 0.0223344
# [368]	valid_0's binary_logloss: 0.0224649
# [369]	valid_0's binary_logloss: 0.0222189
# [370]	valid_0's binary_logloss: 0.022266
# [371]	valid_0's binary_logloss: 0.0221598
# [372]	valid_0's binary_logloss: 0.0222811
# [373]	valid_0's binary_logloss: 0.0223285
# [374]	valid_0's binary_logloss: 0.0219068
# [375]	valid_0's binary_logloss: 0.0219501
# [376]	valid_0's binary_logloss: 0.0218073
# [377]	valid_0's binary_logloss: 0.0218498
# [378]	valid_0's binary_logloss: 0.0217246
# [379]	valid_0's binary_logloss: 0.0217664
# [380]	valid_0's binary_logloss: 0.0216564
# [381]	valid_0's binary_logloss: 0.0216973
# [382]	valid_0's binary_logloss: 0.0216766
# [383]	valid_0's binary_logloss: 0.021516
# [384]	valid_0's binary_logloss: 0.0213593
# [385]	valid_0's binary_logloss: 0.0213985
# [386]	valid_0's binary_logloss: 0.0213842
# [387]	valid_0's binary_logloss: 0.0213532
# [388]	valid_0's binary_logloss: 0.0213348
# [389]	valid_0's binary_logloss: 0.0211787
# [390]	valid_0's binary_logloss: 0.0212174
# [391]	valid_0's binary_logloss: 0.0212145
# [392]	valid_0's binary_logloss: 0.0212521
# [393]	valid_0's binary_logloss: 0.0212328
# [394]	valid_0's binary_logloss: 0.0210048
# [395]	valid_0's binary_logloss: 0.0210436
# [396]	valid_0's binary_logloss: 0.0209458
# [397]	valid_0's binary_logloss: 0.0210652
# [398]	valid_0's binary_logloss: 0.0211026
# [399]	valid_0's binary_logloss: 0.0210829
# [400]	valid_0's binary_logloss: 0.0208625
# Did not meet early stopping. Best iteration is:
# [400]	valid_0's binary_logloss: 0.0208625
# LGBMClassifier(n_estimators=400, objective='binary')

# %%
scores = cross_val_score(lgbm_wrapper, X_train, y_train, cv=3)

print('cross-val-score \n{}'.format(scores))
print('cross-val-score.mean \n{:.3f}'.format(scores.mean()))
# Out:
# cross-val-score
# [0.83333333 0.9        0.8       ]
# cross-val-score.mean
# 0.844

# %%
y_pred = lgbm_wrapper.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
pred_proba = lgbm_wrapper.predict_proba(X_test)
pred_proba
# Out:
# array([[9.96552856e-01, 3.44714383e-03],
#        [9.63694783e-02, 9.03630522e-01],
#        [1.14989646e-06, 9.99998850e-01],
#        [9.59070371e-01, 4.09296287e-02],
#        [8.36668302e-06, 9.99991633e-01],
#        [3.57219070e-02, 9.64278093e-01],
#        [1.19901768e-05, 9.99988010e-01],
#        [9.89618408e-01, 1.03815924e-02],
#        [5.77667787e-02, 9.42233221e-01],
#        [6.05409794e-05, 9.99939459e-01],
#        [9.78197816e-01, 2.18021838e-02],
#        [1.36873825e-06, 9.99998631e-01],
#        [9.90766006e-01, 9.23399412e-03],
#        [9.98031169e-01, 1.96883075e-03],
#        [9.99240317e-01, 7.59682697e-04],
#        [9.89104176e-01, 1.08958240e-02],
#        [4.08488878e-05, 9.99959151e-01],
#        [9.95154292e-01, 4.84570753e-03],
#        [3.83990469e-04, 9.99616010e-01],
#        [6.06168367e-03, 9.93938316e-01],
#        [6.30701761e-02, 9.36929824e-01],
#        [4.00355318e-03, 9.95996447e-01],
#        [9.63694783e-02, 9.03630522e-01]])

# %% [markdown]
# ### * outlier 제거된 데이터로 학습 및 평가

# %%
# outlier제거한 데이터로 학습 및 평가
X_train = data_copy_train.drop(['target'], axis=1)
y_train = data_copy_train['target']

evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=10, eval_metric="logloss", 
                 eval_set=evals, verbose=True)

scores = cross_val_score(lgbm_wrapper, X_train, y_train, cv=3)

print('cross-val-score \n{}'.format(scores))
print('cross-val-score.mean \n{:.3f}'.format(scores.mean()))
# Out:
# [1]	valid_0's binary_logloss: 0.630638
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.612374
# [3]	valid_0's binary_logloss: 0.57632
# [4]	valid_0's binary_logloss: 0.542181
# [5]	valid_0's binary_logloss: 0.530089
# [6]	valid_0's binary_logloss: 0.502592
# [7]	valid_0's binary_logloss: 0.493488
# [8]	valid_0's binary_logloss: 0.486154
# [9]	valid_0's binary_logloss: 0.464675
# [10]	valid_0's binary_logloss: 0.457857
# [11]	valid_0's binary_logloss: 0.440755
# [12]	valid_0's binary_logloss: 0.435003
# [13]	valid_0's binary_logloss: 0.418165
# [14]	valid_0's binary_logloss: 0.412924
# [15]	valid_0's binary_logloss: 0.397672
# [16]	valid_0's binary_logloss: 0.385186
# [17]	valid_0's binary_logloss: 0.379738
# [18]	valid_0's binary_logloss: 0.367031
# [19]	valid_0's binary_logloss: 0.361907
# [20]	valid_0's binary_logloss: 0.351443
# [21]	valid_0's binary_logloss: 0.344821
# [22]	valid_0's binary_logloss: 0.347138
# [23]	valid_0's binary_logloss: 0.337026
# [24]	valid_0's binary_logloss: 0.327391
# [25]	valid_0's binary_logloss: 0.315153
# [26]	valid_0's binary_logloss: 0.30877
# [27]	valid_0's binary_logloss: 0.299397
# [28]	valid_0's binary_logloss: 0.27698
# [29]	valid_0's binary_logloss: 0.261303
# [30]	valid_0's binary_logloss: 0.242639
# [31]	valid_0's binary_logloss: 0.226188
# [32]	valid_0's binary_logloss: 0.212541
# [33]	valid_0's binary_logloss: 0.207911
# [34]	valid_0's binary_logloss: 0.203809
# [35]	valid_0's binary_logloss: 0.193658
# [36]	valid_0's binary_logloss: 0.196043
# [37]	valid_0's binary_logloss: 0.198235
# [38]	valid_0's binary_logloss: 0.194015
# [39]	valid_0's binary_logloss: 0.195196
# [40]	valid_0's binary_logloss: 0.197392
# [41]	valid_0's binary_logloss: 0.194376
# [42]	valid_0's binary_logloss: 0.196715
# [43]	valid_0's binary_logloss: 0.194626
# [44]	valid_0's binary_logloss: 0.194206
# [45]	valid_0's binary_logloss: 0.196171
# Early stopping, best iteration is:
# [35]	valid_0's binary_logloss: 0.193658
# cross-val-score
# [0.91666667 0.91666667 0.83333333]
# cross-val-score.mean
# 0.889

# %%
y_pred = lgbm_wrapper.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# ### * Feature Importance

# %%
feature_imp = pd.DataFrame(sorted(zip(lgbm_wrapper.feature_importances_,X_train.columns)), columns=['Value','Feature'])

plt.figure(figsize=(20, 10))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
sns.set_palette("RdPu")
plt.title('LightGBM Feature importance')
plt.yticks(fontsize=14)
plt.ylabel(''); plt.xlabel('')
plt.show()
